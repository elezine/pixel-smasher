# %%
from water_mask_funcs import create_buffer_mask

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
og_mask = cv2.imread('/data_dir/Shield_Water_Mask/20200709_171108_48_106c_3B_AnalyticMS_SR_no_buffer_mask.tif').astype(float)

# %%
plt.imshow(og_mask[:,:,0])

# %% [markdown]
# some random subset:

# %%
og_mask = og_mask[3000:4000,2000:3000, 0]

# %%
plt.imshow(og_mask)

# %%
buffered = create_buffer_mask(og_mask)

# %%
plt.imshow(buffered)
